# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("2self-reported-loneliness-older-adults2.csv")

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of            Entity Code  Year  po
# 0         Austria  AUT  2005  46
# 1         Belgium  BEL  2005  42
# 2         Denmark  DNK  2005  25
# 3         England  NaN  2018  33
# 4         Finland  FIN  2002  39
# 5          France  FRA  2005  45
# 6         Germany  DEU  2005  37
# 7          Greece  GRC  2005  62
# 8          Israel  ISR  2005  48
# 9           Italy  ITA  2005  47
# 10    Netherlands  NLD  2005  35
# 11          Spain  ESP  2005  40
# 12         Sweden  SWE  2005  30
# 13    Switzerland  CHE  2005  26
# 14  United States  USA  2018  30>

# %%
my_plot = sns.displot(df, y="Entity", x="po", height=8, aspect=1.5, hue="po")
